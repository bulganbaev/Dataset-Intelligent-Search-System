# %%
import csv
import pandas as pd

# %%
text_csv = pd.read_csv("dropbox_datasets_video" ,sep=' ', encoding='utf-8')

# %%
print(text_csv)
# Out:
#      Unnamed: 0                                       dataset_name  \
# 0             0                                Document Similarity
# 1             1                                     legal-datasets
# 2             2                                Text_classification
# 3             3                                     ud120-projects
# 4             4                   Awesome Indic Scene Text Dataset
# 5             5             -text-classification-on-Sogou-datasets
# 6             6          Text-Classification-using-Cornell-Dataset
# 7             7          Text-Classification-using-Cornell-Dataset
# 8             8                Text-Classification-Of-TEDX-Dataset
# 9             9                 SynthesizeTextDetectionDatasetTool
# 10           10                                         dstextnorm
# 11           11                          R-Political-Data-Analysis
# 12           12                           imdb-text-classification
# ...

# %%
for index, row in text_csv.iterrows():
    file = open(r"./descriptions_dataset/text/%d.txt" %index,"w+") 
    file.write(row["text"])
    file.close()
